# %% [markdown]
# # Python Data Type
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Boolean
# Boolean is `True` or `False`

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
a = True

# %%
a
# Out:
# True

# %%
print(a)
# Out:
# True

# %%
type(a)
# Out:
# bool

# %%
b = False

# %%
print(b)
# Out:
# False

# %%
type(b)
# Out:
# bool

# %%
c = 4 != 7

# %%
c
# Out:
# True

# %%
type(c)
# Out:
# bool

# %% [markdown]
# ### Boolean Constructor

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %% [markdown]
# ## Numbers
# `int` `float` `complex`

# %% [markdown]
# #### `int`

# %%
d = 3

# %%
d
# Out:
# 3

# %%
print(d)
# Out:
# 3

# %%
type(d)
# Out:
# int

# %%
e = -8383

# %%
type(e)
# Out:
# int

# %% [markdown]
# #### `float`

# %%
f = 3.142

# %%
print(f)
# Out:
# 3.142

# %%
type(f)
# Out:
# float

# %% [markdown]
# #### `complex`
# ```Python
# a + bj
# ```

# %%
 g = 2 + 5j

# %%
print(g)
# Out:
# (2+5j)

# %%
type(g)
# Out:
# complex

# %% [markdown]
# ### `int`, `float` and `complex` Constructor

# %%
f
# Out:
# 3.142

# %%
type(f)
# Out:
# float

# %%
int(f)
# Out:
# 3

# %%
h = 6.783

# %%
h
# Out:
# 6.783

# %%
type(h)
# Out:
# float

# %%
int(h)
# Out:
# 6

# %%
i = 67

# %%
i
# Out:
# 67

# %%
type(i)
# Out:
# int

# %%
float(i)
# Out:
# 67.0

# %%
complex(i)
# Out:
# (67+0j)
